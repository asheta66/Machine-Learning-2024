# %% [markdown]
# <a href="https://colab.research.google.com/github/asheta66/Machine-Learning-2022/blob/main/Simple%20Linear%20Regression/Data_Analysis_Using_Panda_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Data Analysis Using Panda
# Importing the libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Importing the datasets
import sklearn.datasets

url ='https://raw.githubusercontent.com/asheta66/Machine-Learning-2022/main/Simple%20Linear%20Regression/Salary_Data.csv'
df = pd.read_csv(url)

df
#print(df.head(10))
#print(df.tail(10))
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
# This is a describtion of the data mean, std, min and max "Statistical Data"
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
#Showing the data in the column Outcome from 0-5
df['Salary'][0:5]
# Out:
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# Name: Salary, dtype: float64

# %%
#Showing the data from rows number 0-4
df.iloc[10:15]
# Out:
#     YearsExperience   Salary
# 10              3.9  63218.0
# 11              4.0  55794.0
# 12              4.0  56957.0
# 13              4.1  57081.0
# 14              4.5  61111.0

# %%
# Read a specific position of data
df.iloc[10,1]
# Out:
# 63218.0

# %%
# Pick up rows with specific features
#df.loc[df['Salary'] > "1000"]

# %%
# Sorting data in the df
df.sort_values('Salary')
# Out:
#     YearsExperience    Salary
# 2               1.5   37731.0
# 0               1.1   39343.0
# 4               2.2   39891.0
# 3               2.0   43525.0
# 1               1.3   46205.0
# 7               3.2   54445.0
# 11              4.0   55794.0
# 5               2.9   56642.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 9               3.7   57189.0
# 6               3.0   60150.0
# 14              4.5   61111.0
# 10              3.9   63218.0
# 8               3.2   64445.0
# 16              5.1   66029.0
# 15              4.9   67938.0
# 18              5.9   81363.0
# 17              5.3   83088.0
# 20              6.8   91738.0
# 19              6.0   93940.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 25              9.0  105582.0
# 24              8.7  109431.0
# 27              9.6  112635.0
# 23              8.2  113812.0
# 26              9.5  116969.0
# 29             10.5  121872.0
# 28             10.3  122391.0

# %%
df.sort_values('YearsExperience', ascending=False)
# Out:
#     YearsExperience    Salary
# 29             10.5  121872.0
# 28             10.3  122391.0
# 27              9.6  112635.0
# 26              9.5  116969.0
# 25              9.0  105582.0
# 24              8.7  109431.0
# 23              8.2  113812.0
# 22              7.9  101302.0
# 21              7.1   98273.0
# 20              6.8   91738.0
# 19              6.0   93940.0
# 18              5.9   81363.0
# 17              5.3   83088.0
# 16              5.1   66029.0
# 15              4.9   67938.0
# 14              4.5   61111.0
# 13              4.1   57081.0
# 12              4.0   56957.0
# 11              4.0   55794.0
# 10              3.9   63218.0
# 9               3.7   57189.0
# 8               3.2   64445.0
# 7               3.2   54445.0
# 6               3.0   60150.0
# 5               2.9   56642.0
# 4               2.2   39891.0
# 3               2.0   43525.0
# 2               1.5   37731.0
# 1               1.3   46205.0
# 0               1.1   39343.0

# %%
X, y = df['YearsExperience'], df['Salary']

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state = 0)

# %%
# Add a column to data fram or drop a column to df

df['Total'] = df['Salary'] + df['Salary']  
df
# Out:
#     YearsExperience    Salary     Total
# 0               1.1   39343.0   78686.0
# 1               1.3   46205.0   92410.0
# 2               1.5   37731.0   75462.0
# 3               2.0   43525.0   87050.0
# 4               2.2   39891.0   79782.0
# 5               2.9   56642.0  113284.0
# 6               3.0   60150.0  120300.0
# 7               3.2   54445.0  108890.0
# 8               3.2   64445.0  128890.0
# 9               3.7   57189.0  114378.0
# 10              3.9   63218.0  126436.0
# 11              4.0   55794.0  111588.0
# 12              4.0   56957.0  113914.0
# 13              4.1   57081.0  114162.0
# 14              4.5   61111.0  122222.0
# 15              4.9   67938.0  135876.0
# 16              5.1   66029.0  132058.0
# 17              5.3   83088.0  166176.0
# 18              5.9   81363.0  162726.0
# 19              6.0   93940.0  187880.0
# 20              6.8   91738.0  183476.0
# 21              7.1   98273.0  196546.0
# ...

# %%
from sklearn.utils.validation import column_or_1d
# drop a column from df
df = df.drop(columns=['Total'])
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
#cols = list(df.columns.values)
#df   = df[cols[-1]]
#df

# %%
X_train[0:5]
# Out:
# 17    5.3
# 22    7.9
# 5     2.9
# 16    5.1
# 8     3.2
# Name: YearsExperience, dtype: float64

# %%
y_train[0:5]
# Out:
# 17     83088.0
# 22    101302.0
# 5      56642.0
# 16     66029.0
# 8      64445.0
# Name: Salary, dtype: float64

# %%
# Start drowing the data using matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **Basic Fonts**

# %%
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

HTML("<div style='column-count: 2;'>{}</div>".format(code))
# Out:
# <div style='column-count: 2;'><p>DejaVu Sans: <span style='font-family:DejaVu Sans; font-size: 24px;'>DejaVu Sans</p>
# <p>DejaVu Sans Display: <span style='font-family:DejaVu Sans Display; font-size: 24px;'>DejaVu Sans Display</p>
# <p>DejaVu Sans Mono: <span style='font-family:DejaVu Sans Mono; font-size: 24px;'>DejaVu Sans Mono</p>
# <p>DejaVu Serif: <span style='font-family:DejaVu Serif; font-size: 24px;'>DejaVu Serif</p>
# <p>DejaVu Serif Display: <span style='font-family:DejaVu Serif Display; font-size: 24px;'>DejaVu Serif Display</p>
# <p>Humor Sans: <span style='font-family:Humor Sans; font-size: 24px;'>Humor Sans</p>
# <p>Liberation Mono: <span style='font-family:Liberation Mono; font-size: 24px;'>Liberation Mono</p>
# <p>Liberation Sans: <span style='font-family:Liberation Sans; font-size: 24px;'>Liberation Sans</p>
# <p>Liberation Sans Narrow: <span style='font-family:Liberation Sans Narrow; font-size: 24px;'>Liberation Sans Narrow</p>
# ...

# %% [markdown]
# **### Basic Graph**

# %%
plt.plot(df['YearsExperience'],df['Salary'])
plt.grid(True)
plt.show()

# %%
fig, axs = plt.subplots(figsize=(6, 4), tight_layout=True)
plt.plot(df['YearsExperience'], df['Salary'], '-b', label='Salary')
plt.xlabel('Years of Experience', fontname= 'Liberation Serif', fontsize=14, color='g')
plt.ylabel('Salary', fontname= 'Liberation Serif', fontsize=14, color='m')
plt.title('Years Experience vs Salary', fontname= 'Liberation Serif', fontsize=14, color='b')
plt.ylim(np.min(y_train)-1, np.max(y_train)+1)
plt.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, frameon=True, loc='lower center', ncol=2)
plt.grid(True)
#plt.legend()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
# make a little extra space between the subplots
fig.subplots_adjust(hspace=0.5)

ax1.plot(df['YearsExperience'], '-b', label='YearsExperience')
ax1.set_xlabel('Time', fontname= 'Liberation Serif', fontsize=14, color='b')
ax1.set_ylabel('Years', fontname= 'Liberation Serif', fontsize=14, color='b')
ax1.grid(True)


ax2.plot(df['Salary'], '-b', label='Salary')
ax2.set_xlabel('Time', fontname= 'Liberation Serif', fontsize=14, color='b')
ax2.set_ylabel('Salary', fontname= 'Liberation Serif', fontsize=14, color='b')
ax2.grid(True)

plt.show()
