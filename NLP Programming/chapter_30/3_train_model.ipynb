# %% [markdown]
# <a href="https://colab.research.google.com/github/asheta66/Machine-Learning-2020/blob/main/NLP%20Programming/chapter_30/3_train_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Acquireing datasets
# !git clone https://github.com/asheta66/Machine-Learning-2020
# Create Model via another notebook
# %run Machine-Learning-2020/NLP\ Programming/chapter_30/2_split_data.ipynb
# Out:
# Cloning into 'Machine-Learning-2020'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 3102 (delta 87), reused 3 (delta 0), pack-reused 2977
# Receiving objects: 100% (3102/3102), 37.29 MiB | 17.97 MiB/s, done.
# Resolving deltas: 100% (731/731), done.
# fatal: destination path 'Machine-Learning-2020' already exists and is not an empty directory.
# fatal: destination path 'Machine-Learning-2020' already exists and is not an empty directory.
# /content/Machine-Learning-2020/Datasets/NLP
# Saved: english-german.pkl
# [go] => [geh]
# [hi] => [hallo]
# [hi] => [gru gott]
# [run] => [lauf]
# [run] => [lauf]
# [wow] => [potzdonner]
# [wow] => [donnerwetter]
# [fire] => [feuer]
# [help] => [hilfe]
# [help] => [zu hulf]
# [stop] => [stopp]
# [stop] => [anhalten]
# [wait] => [warte]
# [wait] => [warte]
# [begin] => [fang an]
# [go on] => [mach weiter]
# [hello] => [hallo]
# [hello] => [sers]
# [hurry] => [beeil dich]
# [hurry] => [schnell]
# [i hid] => [ich versteckte mich]
# [i hid] => [ich habe mich versteckt]
# [i ran] => [ich rannte]
# [i see] => [ich verstehe]
# [i see] => [aha]
# [i try] => [ich probiere es]
# [i won] => [ich hab gewonnen]
# [i won] => [ich habe gewonnen]
# [relax] => [entspann dich]
# [shoot] => [feuer]
# [shoot] => [schie]
# [smile] => [lacheln]
# [ask me] => [frag mich]
# [ask me] => [fragt mich]
# [ask me] => [fragen sie mich]
# [attack] => [angriff]
# [attack] => [attacke]
# [cheers] => [zum wohl]
# [eat it] => [iss es]
# [eat up] => [iss auf]
# [eat up] => [iss auf]
# [freeze] => [keine bewegung]
# [freeze] => [stehenbleiben]
# [go now] => [geh jetzt]
# [got it] => [verstanden]
# [got it] => [ich habs]
# [got it] => [aha]
# [got it] => [kapiert]
# [got it] => [verstanden]
# [got it] => [einverstanden]
# [he ran] => [er rannte]
# [he ran] => [er lief]
# [hop in] => [mach mit]
# [hop in] => [spring rein]
# [hug me] => [druck mich]
# [hug me] => [nimm mich in den arm]
# [hug me] => [umarme mich]
# [i care] => [mir ist es wichtig]
# [i fell] => [ich fiel]
# [i fell] => [ich fiel hin]
# [i fell] => [ich sturzte]
# [i fell] => [ich bin hingefallen]
# [i fell] => [ich bin gesturzt]
# [i fled] => [ich fluchtete]
# [i fled] => [ich bin gefluchtet]
# [i know] => [ich wei]
# [i lied] => [ich habe gelogen]
# [i lost] => [ich habe verloren]
# [i paid] => [ich habe bezahlt]
# [i paid] => [ich zahlte]
# [i sang] => [ich sang]
# [i spit] => [ich spuckte]
# [i spit] => [ich habe gespuckt]
# [i swim] => [ich schwimme]
# [i wept] => [ich weinte]
# [i wept] => [ich habe geweint]
# [im] => [ich bin jahre alt]
# [im] => [ich bin]
# [im ok] => [mir gehts gut]
# [im ok] => [es geht mir gut]
# [im up] => [ich bin wach]
# [im up] => [ich bin auf]
# [listen] => [hort zu]
# [no way] => [unmoglich]
# [no way] => [das kommt nicht in frage]
# [no way] => [das gibts doch nicht]
# [no way] => [ausgeschlossen]
# [no way] => [in keinster weise]
# [really] => [wirklich]
# [really] => [echt]
# [really] => [im ernst]
# [thanks] => [danke]
# [try it] => [versuchs]
# [we try] => [wir versuchen es]
# [we won] => [wir haben gewonnen]
# [why me] => [warum ich]
# [ask tom] => [frag tom]
# [ask tom] => [fragen sie tom]
# [ask tom] => [fragt tom]
# [awesome] => [fantastisch]
# Saved: english-german-both.pkl
# Saved: english-german-train.pkl
# Saved: english-german-test.pkl

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	# compile model
	model.compile(optimizer='adam', loss='categorical_crossentropy')
	# summarize defined model
	model.summary()
	plot_model(model, to_file='model.png', show_shapes=True)
	return model

# load datasets
dataset = load_clean_sentences('english-german-both.pkl')
train = load_clean_sentences('english-german-train.pkl')
test = load_clean_sentences('english-german-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('German Vocabulary Size: %d' % ger_vocab_size)
print('German Max Length: %d' % (ger_length))
# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)
# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
# fit model
checkpoint = ModelCheckpoint('model.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=30, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 2249
# English Max Length: 5
# German Vocabulary Size: 3581
# German Max Length: 9
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 9, 256)            916736
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 5, 256)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 5, 2249)           577993
# =================================================================
# Total params: 2,545,353
# Trainable params: 2,545,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 141/141 - 10s - loss: 4.1397 - val_loss: 3.3553
#
# Epoch 00001: val_loss improved from inf to 3.35527, saving model to model.h5
# Epoch 2/30
# 141/141 - 2s - loss: 3.2182 - val_loss: 3.2099
#
# Epoch 00002: val_loss improved from 3.35527 to 3.20993, saving model to model.h5
# Epoch 3/30
# 141/141 - 2s - loss: 3.0828 - val_loss: 3.1366
#
# Epoch 00003: val_loss improved from 3.20993 to 3.13663, saving model to model.h5
# Epoch 4/30
# 141/141 - 2s - loss: 2.9543 - val_loss: 3.0161
#
# Epoch 00004: val_loss improved from 3.13663 to 3.01611, saving model to model.h5
# Epoch 5/30
# 141/141 - 2s - loss: 2.7868 - val_loss: 2.9222
#
# Epoch 00005: val_loss improved from 3.01611 to 2.92221, saving model to model.h5
# Epoch 6/30
# 141/141 - 2s - loss: 2.6477 - val_loss: 2.8121
#
# Epoch 00006: val_loss improved from 2.92221 to 2.81211, saving model to model.h5
# Epoch 7/30
# 141/141 - 2s - loss: 2.5079 - val_loss: 2.6991
#
# Epoch 00007: val_loss improved from 2.81211 to 2.69915, saving model to model.h5
# Epoch 8/30
# 141/141 - 2s - loss: 2.3596 - val_loss: 2.6136
#
# Epoch 00008: val_loss improved from 2.69915 to 2.61360, saving model to model.h5
# Epoch 9/30
# 141/141 - 2s - loss: 2.2322 - val_loss: 2.5328
#
# Epoch 00009: val_loss improved from 2.61360 to 2.53277, saving model to model.h5
# Epoch 10/30
# 141/141 - 2s - loss: 2.0949 - val_loss: 2.4388
#
# Epoch 00010: val_loss improved from 2.53277 to 2.43878, saving model to model.h5
# Epoch 11/30
# 141/141 - 2s - loss: 1.9655 - val_loss: 2.3697
#
# Epoch 00011: val_loss improved from 2.43878 to 2.36970, saving model to model.h5
# Epoch 12/30
# 141/141 - 2s - loss: 1.8460 - val_loss: 2.2996
#
# Epoch 00012: val_loss improved from 2.36970 to 2.29960, saving model to model.h5
# Epoch 13/30
# 141/141 - 2s - loss: 1.7340 - val_loss: 2.2278
#
# Epoch 00013: val_loss improved from 2.29960 to 2.22780, saving model to model.h5
# Epoch 14/30
# 141/141 - 2s - loss: 1.6274 - val_loss: 2.1948
#
# Epoch 00014: val_loss improved from 2.22780 to 2.19477, saving model to model.h5
# Epoch 15/30
# 141/141 - 2s - loss: 1.5323 - val_loss: 2.1273
#
# Epoch 00015: val_loss improved from 2.19477 to 2.12733, saving model to model.h5
# Epoch 16/30
# 141/141 - 2s - loss: 1.4331 - val_loss: 2.0869
#
# Epoch 00016: val_loss improved from 2.12733 to 2.08687, saving model to model.h5
# Epoch 17/30
# 141/141 - 2s - loss: 1.3409 - val_loss: 2.0508
#
# Epoch 00017: val_loss improved from 2.08687 to 2.05083, saving model to model.h5
# Epoch 18/30
# 141/141 - 2s - loss: 1.2524 - val_loss: 2.0184
#
# Epoch 00018: val_loss improved from 2.05083 to 2.01839, saving model to model.h5
# Epoch 19/30
# 141/141 - 2s - loss: 1.1628 - val_loss: 1.9685
#
# Epoch 00019: val_loss improved from 2.01839 to 1.96848, saving model to model.h5
# Epoch 20/30
# 141/141 - 2s - loss: 1.0830 - val_loss: 1.9531
#
# Epoch 00020: val_loss improved from 1.96848 to 1.95308, saving model to model.h5
# Epoch 21/30
# 141/141 - 2s - loss: 1.0014 - val_loss: 1.9300
#
# Epoch 00021: val_loss improved from 1.95308 to 1.92996, saving model to model.h5
# Epoch 22/30
# 141/141 - 2s - loss: 0.9263 - val_loss: 1.9033
#
# Epoch 00022: val_loss improved from 1.92996 to 1.90329, saving model to model.h5
# Epoch 23/30
# 141/141 - 2s - loss: 0.8558 - val_loss: 1.8892
#
# Epoch 00023: val_loss improved from 1.90329 to 1.88918, saving model to model.h5
# Epoch 24/30
# 141/141 - 2s - loss: 0.7870 - val_loss: 1.8519
#
# Epoch 00024: val_loss improved from 1.88918 to 1.85190, saving model to model.h5
# Epoch 25/30
# 141/141 - 2s - loss: 0.7239 - val_loss: 1.8511
#
# Epoch 00025: val_loss improved from 1.85190 to 1.85112, saving model to model.h5
# Epoch 26/30
# 141/141 - 2s - loss: 0.6595 - val_loss: 1.8232
#
# Epoch 00026: val_loss improved from 1.85112 to 1.82322, saving model to model.h5
# Epoch 27/30
# 141/141 - 2s - loss: 0.6053 - val_loss: 1.8243
#
# Epoch 00027: val_loss did not improve from 1.82322
# Epoch 28/30
# 141/141 - 2s - loss: 0.5545 - val_loss: 1.8149
#
# Epoch 00028: val_loss improved from 1.82322 to 1.81491, saving model to model.h5
# Epoch 29/30
# 141/141 - 2s - loss: 0.5053 - val_loss: 1.8045
#
# Epoch 00029: val_loss improved from 1.81491 to 1.80451, saving model to model.h5
# Epoch 30/30
# 141/141 - 2s - loss: 0.4631 - val_loss: 1.8002
#
# Epoch 00030: val_loss improved from 1.80451 to 1.80017, saving model to model.h5
