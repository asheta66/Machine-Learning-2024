# %% [markdown]
# <a href="https://colab.research.google.com/github/asheta66/Machine-Learning-2020/blob/main/NLP%20Programming/chapter_18/2_train_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Acquireing datasets
# !git clone https://github.com/asheta66/Machine-Learning-2020
# Create Model via another notebook
# %run Machine-Learning-2020/NLP\ Programming/chapter_18/1_prepare_data.ipynb

# %%
from numpy import array
from pickle import dump
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# define the model
def define_model(X):
	model = Sequential()
	model.add(LSTM(75, input_shape=(X.shape[1], X.shape[2])))
	model.add(Dense(vocab_size, activation='softmax'))
	# compile model
	model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	# summarize defined model
	model.summary()
	plot_model(model, to_file='model.png', show_shapes=True)
	return model

# load
in_filename = 'char_sequences.txt'
raw_text = load_doc(in_filename)
lines = raw_text.split('\n')
# integer encode sequences of characters
chars = sorted(list(set(raw_text)))
mapping = dict((c, i) for i, c in enumerate(chars))
sequences = list()
for line in lines:
	# integer encode line
	encoded_seq = [mapping[char] for char in line]
	# store
	sequences.append(encoded_seq)
# vocabulary size
vocab_size = len(mapping)
print('Vocabulary Size: %d' % vocab_size)
# separate into input and output
sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
sequences = [to_categorical(x, num_classes=vocab_size) for x in X]
X = array(sequences)
y = to_categorical(y, num_classes=vocab_size)
# define model
model = define_model(X)
# fit model
model.fit(X, y, epochs=100, verbose=2)
# save the model to file
model.save('model.h5')
# save the mapping
dump(mapping, open('mapping.pkl', 'wb'))
# Out:
# Vocabulary Size: 38
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 75)                34200
# _________________________________________________________________
# dense (Dense)                (None, 38)                2888
# =================================================================
# Total params: 37,088
# Trainable params: 37,088
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 13/13 - 2s - loss: 3.6120 - accuracy: 0.0927
# Epoch 2/100
# 13/13 - 0s - loss: 3.4855 - accuracy: 0.1930
# Epoch 3/100
# 13/13 - 0s - loss: 3.1401 - accuracy: 0.1905
# Epoch 4/100
# 13/13 - 0s - loss: 3.0582 - accuracy: 0.1905
# Epoch 5/100
# 13/13 - 0s - loss: 3.0056 - accuracy: 0.1905
# Epoch 6/100
# 13/13 - 0s - loss: 2.9875 - accuracy: 0.1905
# Epoch 7/100
# 13/13 - 0s - loss: 2.9716 - accuracy: 0.1905
# Epoch 8/100
# 13/13 - 0s - loss: 2.9610 - accuracy: 0.1905
# Epoch 9/100
# 13/13 - 0s - loss: 2.9495 - accuracy: 0.1905
# Epoch 10/100
# 13/13 - 0s - loss: 2.9294 - accuracy: 0.1905
# Epoch 11/100
# 13/13 - 0s - loss: 2.9166 - accuracy: 0.1905
# Epoch 12/100
# 13/13 - 0s - loss: 2.8968 - accuracy: 0.1905
# Epoch 13/100
# 13/13 - 0s - loss: 2.8694 - accuracy: 0.1955
# Epoch 14/100
# 13/13 - 0s - loss: 2.8467 - accuracy: 0.1930
# Epoch 15/100
# 13/13 - 0s - loss: 2.8237 - accuracy: 0.1980
# Epoch 16/100
# 13/13 - 0s - loss: 2.7906 - accuracy: 0.2130
# Epoch 17/100
# 13/13 - 0s - loss: 2.7572 - accuracy: 0.2206
# Epoch 18/100
# 13/13 - 0s - loss: 2.7206 - accuracy: 0.2180
# Epoch 19/100
# 13/13 - 0s - loss: 2.6811 - accuracy: 0.2607
# Epoch 20/100
# 13/13 - 0s - loss: 2.6408 - accuracy: 0.2682
# Epoch 21/100
# 13/13 - 0s - loss: 2.6084 - accuracy: 0.2406
# Epoch 22/100
# 13/13 - 0s - loss: 2.5559 - accuracy: 0.2632
# Epoch 23/100
# 13/13 - 0s - loss: 2.5303 - accuracy: 0.3108
# Epoch 24/100
# 13/13 - 0s - loss: 2.4834 - accuracy: 0.2807
# Epoch 25/100
# 13/13 - 0s - loss: 2.4277 - accuracy: 0.3133
# Epoch 26/100
# 13/13 - 0s - loss: 2.3817 - accuracy: 0.3333
# Epoch 27/100
# 13/13 - 0s - loss: 2.3509 - accuracy: 0.3308
# Epoch 28/100
# 13/13 - 0s - loss: 2.3110 - accuracy: 0.3534
# Epoch 29/100
# 13/13 - 0s - loss: 2.2515 - accuracy: 0.3409
# Epoch 30/100
# 13/13 - 0s - loss: 2.2333 - accuracy: 0.3534
# Epoch 31/100
# 13/13 - 0s - loss: 2.1801 - accuracy: 0.4035
# Epoch 32/100
# 13/13 - 0s - loss: 2.1583 - accuracy: 0.3559
# Epoch 33/100
# 13/13 - 0s - loss: 2.1243 - accuracy: 0.4010
# Epoch 34/100
# 13/13 - 0s - loss: 2.0855 - accuracy: 0.4110
# Epoch 35/100
# 13/13 - 0s - loss: 2.0200 - accuracy: 0.4436
# Epoch 36/100
# 13/13 - 0s - loss: 1.9711 - accuracy: 0.4386
# Epoch 37/100
# 13/13 - 0s - loss: 1.9264 - accuracy: 0.4637
# Epoch 38/100
# 13/13 - 0s - loss: 1.8907 - accuracy: 0.4737
# Epoch 39/100
# 13/13 - 0s - loss: 1.8626 - accuracy: 0.4862
# Epoch 40/100
# 13/13 - 0s - loss: 1.8224 - accuracy: 0.4962
# Epoch 41/100
# 13/13 - 0s - loss: 1.7715 - accuracy: 0.5138
# Epoch 42/100
# 13/13 - 0s - loss: 1.7368 - accuracy: 0.5113
# Epoch 43/100
# 13/13 - 0s - loss: 1.6955 - accuracy: 0.5363
# Epoch 44/100
# 13/13 - 0s - loss: 1.6547 - accuracy: 0.5464
# Epoch 45/100
# 13/13 - 0s - loss: 1.6035 - accuracy: 0.5564
# Epoch 46/100
# 13/13 - 0s - loss: 1.5767 - accuracy: 0.5815
# Epoch 47/100
# 13/13 - 0s - loss: 1.5487 - accuracy: 0.6015
# Epoch 48/100
# 13/13 - 0s - loss: 1.5024 - accuracy: 0.6291
# Epoch 49/100
# 13/13 - 0s - loss: 1.4534 - accuracy: 0.6291
# Epoch 50/100
# 13/13 - 0s - loss: 1.4341 - accuracy: 0.6491
# Epoch 51/100
# 13/13 - 0s - loss: 1.3870 - accuracy: 0.6717
# Epoch 52/100
# 13/13 - 0s - loss: 1.3502 - accuracy: 0.6692
# Epoch 53/100
# 13/13 - 0s - loss: 1.2977 - accuracy: 0.6992
# Epoch 54/100
# 13/13 - 0s - loss: 1.2612 - accuracy: 0.7093
# Epoch 55/100
# 13/13 - 0s - loss: 1.2242 - accuracy: 0.7093
# Epoch 56/100
# 13/13 - 0s - loss: 1.1810 - accuracy: 0.7368
# Epoch 57/100
# 13/13 - 0s - loss: 1.1645 - accuracy: 0.7118
# Epoch 58/100
# 13/13 - 0s - loss: 1.1291 - accuracy: 0.7494
# Epoch 59/100
# 13/13 - 0s - loss: 1.0799 - accuracy: 0.7744
# Epoch 60/100
# 13/13 - 0s - loss: 1.0493 - accuracy: 0.7820
# Epoch 61/100
# 13/13 - 0s - loss: 1.0231 - accuracy: 0.7669
# Epoch 62/100
# 13/13 - 0s - loss: 0.9864 - accuracy: 0.7970
# Epoch 63/100
# 13/13 - 0s - loss: 0.9612 - accuracy: 0.8070
# Epoch 64/100
# 13/13 - 0s - loss: 0.9297 - accuracy: 0.8271
# Epoch 65/100
# 13/13 - 0s - loss: 0.8964 - accuracy: 0.8246
# Epoch 66/100
# 13/13 - 0s - loss: 0.8598 - accuracy: 0.8596
# Epoch 67/100
# 13/13 - 0s - loss: 0.8364 - accuracy: 0.8371
# Epoch 68/100
# 13/13 - 0s - loss: 0.8079 - accuracy: 0.8747
# Epoch 69/100
# 13/13 - 0s - loss: 0.7754 - accuracy: 0.8622
# Epoch 70/100
# 13/13 - 0s - loss: 0.7475 - accuracy: 0.8872
# Epoch 71/100
# 13/13 - 0s - loss: 0.7057 - accuracy: 0.8947
# Epoch 72/100
# 13/13 - 0s - loss: 0.6813 - accuracy: 0.9023
# Epoch 73/100
# 13/13 - 0s - loss: 0.6523 - accuracy: 0.9123
# Epoch 74/100
# 13/13 - 0s - loss: 0.6335 - accuracy: 0.9073
# Epoch 75/100
# 13/13 - 0s - loss: 0.6108 - accuracy: 0.9273
# Epoch 76/100
# 13/13 - 0s - loss: 0.5792 - accuracy: 0.9298
# Epoch 77/100
# 13/13 - 0s - loss: 0.5581 - accuracy: 0.9424
# Epoch 78/100
# 13/13 - 0s - loss: 0.5371 - accuracy: 0.9449
# Epoch 79/100
# 13/13 - 0s - loss: 0.5153 - accuracy: 0.9474
# Epoch 80/100
# 13/13 - 0s - loss: 0.5010 - accuracy: 0.9599
# Epoch 81/100
# 13/13 - 0s - loss: 0.4816 - accuracy: 0.9424
# Epoch 82/100
# 13/13 - 0s - loss: 0.4539 - accuracy: 0.9649
# Epoch 83/100
# 13/13 - 0s - loss: 0.4372 - accuracy: 0.9574
# Epoch 84/100
# 13/13 - 0s - loss: 0.4219 - accuracy: 0.9674
# Epoch 85/100
# 13/13 - 0s - loss: 0.4109 - accuracy: 0.9674
# Epoch 86/100
# 13/13 - 0s - loss: 0.3995 - accuracy: 0.9724
# Epoch 87/100
# 13/13 - 0s - loss: 0.3796 - accuracy: 0.9724
# Epoch 88/100
# 13/13 - 0s - loss: 0.3699 - accuracy: 0.9724
# Epoch 89/100
# 13/13 - 0s - loss: 0.3528 - accuracy: 0.9774
# Epoch 90/100
# 13/13 - 0s - loss: 0.3321 - accuracy: 0.9749
# Epoch 91/100
# 13/13 - 0s - loss: 0.3217 - accuracy: 0.9850
# Epoch 92/100
# 13/13 - 0s - loss: 0.3024 - accuracy: 0.9799
# Epoch 93/100
# 13/13 - 0s - loss: 0.2911 - accuracy: 0.9875
# Epoch 94/100
# 13/13 - 0s - loss: 0.2799 - accuracy: 0.9825
# Epoch 95/100
# 13/13 - 0s - loss: 0.2724 - accuracy: 0.9850
# Epoch 96/100
# 13/13 - 0s - loss: 0.2574 - accuracy: 0.9850
# Epoch 97/100
# 13/13 - 0s - loss: 0.2511 - accuracy: 0.9850
# Epoch 98/100
# 13/13 - 0s - loss: 0.2411 - accuracy: 0.9875
# Epoch 99/100
# 13/13 - 0s - loss: 0.2299 - accuracy: 0.9875
# Epoch 100/100
# 13/13 - 0s - loss: 0.2226 - accuracy: 0.9875
